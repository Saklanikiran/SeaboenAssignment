# %% [markdown]
# # Ans : 1

# %%
# Plots using seaborn
'''
1. Scatter Plot:
   - Use: To visualize the relationship between two continuous variables.
   - Example uses: Analyzing the correlation between height and weight, plotting data points in a two-dimensional space to identify patterns.
   
2. Histogram:
   - Use: To display the distribution of a single continuous variable.
   - Example uses: Showing the distribution of ages in a population, visualizing the frequency distribution of test scores.

3. Bar Plot:
   - Use: To compare the mean or aggregate of a categorical variable.
   - Example uses: Comparing average sales revenue across different regions, visualizing the count of cars of different brands.

4. Line Plot:
   - Use: To display the trend of a continuous variable over time or another continuous variable.
   - Example uses: Showing the stock price movement over a period of time, visualizing the change in temperature throughout the day.

5. Box Plot (or Box-and-Whisker Plot
   - Use: To summarize the distribution of a continuous variable and identify potential outliers.
   - Example uses: Analyzing the distribution of salaries in a company, comparing the distribution of heights between different age groups.

Seaborn offers easy-to-use functions for creating these plots with customization options to enhance their visual appeal and effectiveness in conveying insights from data.

'''

# %% [markdown]
# # Ans : 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fmri_data = sns.load_dataset("fmri")

plt.figure(figsize=(10, 6))
sns.lineplot(data=fmri_data, x="timepoint", y="signal", hue="event", style="region", markers=True, dashes=False)

plt.title("FMRI Signal over Time by Event and Region")
plt.xlabel("Timepoint")
plt.ylabel("Signal")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ans : 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic_data = sns.load_dataset("titanic")

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x='pclass', y='age', data=titanic_data)
plt.title('Age Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')

plt.subplot(1, 2, 2)
sns.boxplot(x='pclass', y='fare', data=titanic_data)
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')

plt.tight_layout()

plt.show()

# %% [markdown]
# # Ans : 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

diamonds_data = sns.load_dataset("diamonds")

plt.figure(figsize=(10, 6))
sns.histplot(data=diamonds_data, x='price', hue='cut', bins=30, kde=True, palette='husl')

plt.title('Histogram of Diamond Prices by Cut')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.legend(title='Cut')  
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Ans : 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris_data = sns.load_dataset("iris")

sns.pairplot(data=iris_data, hue='species', palette='Set1')

plt.title('Pair Plot of Iris Dataset by Species')
plt.show()

# %% [markdown]
# # Ans : 6
